# %% [markdown]
# # Extra Task 2

# %% [markdown]
# ### In the following questions, use Pandas and Matplotlib to visualize Company Sales Data.
# - Note: Read this data using Pandas or NumPy or using in-built matplotlib function.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\Anwar Altorkmani\\Desktop\\Shai for ai\\task4\\company_sales_data.csv")
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1. Using a line plot visualize the Total profit data provided for each month.
#
# **Note:**It must be implemented in three methods
# - Generated line plot must include the following properties:
#
# X axis name = Month Number <br>
# Y axis name = Total profit <br>
# The line plot graph should look like this.
# ![image.png](attachment:image.png)

# %%
####################################### Line Plot using Matplotlib visualization #########################################

# %%
profitList = df ['total_profit'].tolist()
monthList  = df ['month_number'].tolist()
plt.plot(monthList, profitList, label = 'Month-wise Profit data of last year')
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %%
####################################### Line Plot using Seaborn visualization #########################################

# %%
sns.lineplot(x='month_number',y='total_profit', data=df)
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %%
#################################### Line Plot using Pandas visualization #####################################

# %%
ax = df.plot.line(x='month_number', y='total_profit')
plt.xlabel('Month number')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.ylabel('Profit in dollar')
plt.show()

# %% [markdown]
# #### 2. Read all product sales data and display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
# **Note:**It must be implemented in three methods
# The graph should look like this.
# ![image.png](attachment:image.png)

# %%
############################## multiline plots using Matplotlib visualization #########################################

# %%
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot(monthList, faceCremSalesData,   label = 'Face cream Sales Data', marker='o',markersize=12, linewidth=3)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o',markersize=12, linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', markersize=12, linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathingsoup Sales Data', marker='o', markersize=12, linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'Shampoo', marker='o', linewidth=4)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturizer Sales Data', marker='o',markersize=12, linewidth=3)

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %%
########################### multiline plots Plot using Seaborn visualization #########################################

# %%
sns.lineplot(x=monthList, y=faceCremSalesData,   label = 'Face cream Sales Data', marker='o',markersize=12, linewidth=3)
sns.lineplot(x=monthList, y=faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o',markersize=12, linewidth=3)
sns.lineplot(x=monthList, y=toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o',markersize=12, linewidth=3)
sns.lineplot(x=monthList, y=bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o',markersize=12, linewidth=3)
sns.lineplot(x=monthList, y=shampooSalesData, label = 'ToothPaste Sales Data', marker='o',markersize=12, linewidth=3)
sns.lineplot(x=monthList, y=moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o',markersize=12, linewidth=3)

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %%
#################################### multiline plots using Pandas visualization #####################################

# %%
df.facecream.plot(x='month_number',y='facecream', label = 'Face cream Sales Data', marker='o',markersize=12,color='orange',linewidth=3)
df.facewash.plot(x='month_number',y='facewash', label = 'Face Wash Sales Data ', marker='o',markersize=12,color='blue', linewidth=3)
df.toothpaste.plot(x='month_number',y='toothpaste', label = 'ToothPaste Sales Data', marker='o',markersize=12,color='green', linewidth=3)
df.bathingsoap.plot(x='month_number',y='bathingsoap', label = 'Bathingsoup Sales Data', marker='o',markersize=12,color='red', linewidth=3)
df.shampoo.plot(x='month_number',y='shampoo', label = 'Shampoo Sales Data', marker='o',markersize=12,color='purple', linewidth=3)
df.moisturizer.plot(x='month_number',y='moisturizer', label = 'Moisturizer Sales Data', marker='o',markersize=12,color='brown', linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %% [markdown]
# #### 3. Read face cream and facewash product sales data and show it using the bar chart.
#
#
# - The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
# - **Note:**It must be implemented in three methods
#
# The bar chart should look like this.
# ![image.png](attachment:image.png)

# %%
#################################### bar Plot using Matplotlib visualization #########################################

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\Anwar Altorkmani\\Desktop\\Shai for ai\\task4\\company_sales_data.csv')
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream sales data', align='edge')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash sales data', align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
plt.show()

# %%
####################################### bar Plot using Seaborn visualization #########################################

# %%
###################back############################
sns.barplot(x =monthList,y =faceCremSalesData,label='Face cream sales data',data = df,palette ="Blues")
sns.barplot(x =monthList,y =faceWashSalesData,label='Face wash sales data',data = df,palette = "Blues_r")
plt.xlabel('Month Number')
plt.ylabel('facewash')
plt.legend(loc='upper left')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.show()

# %%
#################################### bar Plot using Pandas visualization #####################################

# %%
width = 0.4
df.facecream.plot(kind='bar', color='blue',label = 'Face Cream sales data', width=width, position=1)
df.facewash.plot(kind='bar', color='orange', label = 'Face Wash sales data', width=width, position=0)
plt.xlabel('Month Number')
plt.ylabel('facewash')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(monthList)
plt.grid(True, linewidth= 2, linestyle="--")
plt.show()

# %% [markdown]
# #### 4. Read sales data of bathing soap of all months and show it using a bar chart.
# **Note:**It must be implemented in three methods.
# The bar chart should look like this.
# ![image.png](attachment:image.png)

# %%
####################################### bar Plot using Matplotlib #########################################

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\Anwar Altorkmani\\Desktop\\Shai for ai\\task4\\company_sales_data.csv')
monthList  = df ['month_number'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
plt.bar(monthList, bathingsoapSalesData)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 2, linestyle="--")
plt.title('bathingsoap sales data')
plt.show()

# %%
####################################### bar Plot using Seaborn  visualization#########################################

# %%
sns.barplot(data=df,x=monthList, y=bathingsoapSalesData,color='blue')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 2, linestyle="--")
plt.title('bathingsoap sales data')
plt.show()

# %%
#################################### bar Plot using Pandas visualization #####################################

# %%
df.month_number.plot.bar()
df.bathingsoap.plot.bar()
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 2, linestyle="--")
plt.title('bathingsoap sales data')
plt.show()

# %% [markdown]
# #### 5. Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# **Note:**It must be implemented in three methods.
# The histogram should look like this.
# ![image.png](attachment:image.png)

# %%
####################################### histogram Plot using Matplotlib visualization #########################################

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\Anwar Altorkmani\\Desktop\\Shai for ai\\task4\\company_sales_data.csv')
profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
plt.hist(profitList, profit_range, label = 'Profit data')
plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.legend(loc='upper left')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %%
####################################### histogram  Plot using Seaborn visualization #########################################

# %%
fig = plt.figure()
#sns.histplot(data=df, x=profitList, bins=7,binwidth=3)
sns.histplot(data=df, x=profitList,  bins =profit_range,label = 'Profit data')
plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.legend(loc='upper left')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %%
#################################### histogram Plot using Pandas visualization #####################################

# %%
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
df.total_profit.plot.hist(bins =profit_range,label = 'Profit data', color='blue')
plt.xlabel('profit range in dollar')
plt.ylabel('Actual Profit in dollar')
plt.legend(loc='upper left')
plt.xticks(profit_range)
plt.title('Profit data')
plt.show()

# %% [markdown]
# #### 6. Calculate total sale data for last year for each product and show it using a Pie chart.
# - **Note:**
#     - In Pie chart display Number of units sold per year for each product in percentage.
#     - It must be implemented in two methods.
#
# The Pie chart should look like this.
# ![image.png](attachment:image.png)

# %%
#################################### pie Plot using Matplotlib visualization #####################################

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\Anwar Altorkmani\\Desktop\\Shai for ai\\task4\\company_sales_data.csv')
monthList  = df ['month_number'].tolist()

labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(),
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# %%
#################################### pie Plot using Pandas visualization #####################################

# %%
import pandas as pd
# pandas series Wimbledon winners from 2015 to 2019
salesData = pd.Series(index=['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer'] ,
                   data=[df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()],
                   name='Sales data')
#salesData_count = salesData.value_counts()

#salesData.plot(kind='pie')
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()
